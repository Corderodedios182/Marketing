# %%
#Paqueterías a usar

import os 
import glob
import re 

import numpy as np
import pandas as pd

import random
import warnings

import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.offline as pyo
import plotly.express as px
import plotly.graph_objects as go

warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '%.f' % x)

os.chdir('/home/carlos/Documentos/3_Adsocial/Marketing/Analytics/librerias')
os.listdir()
#librería creada con funciones para facilitar la lectura del cuaderno jupyter.
import analytics_funciones

# %%
#Union archivos Office Depot
audiencia_afinidad = analytics_funciones.Union_Archivos(Cuenta = ['Office Depot'], analysis = 'categorias_afinidad', nivel = 'Audiencia')

#Fechas
audiencia_afinidad['fechas'] = [ re.findall( r"\d{8}-\d{8}" ,i) for i in audiencia_afinidad.archivo ]
audiencia_afinidad = analytics_funciones.Formato_Fechas_Analytics(audiencia_afinidad, 'fechas')
audiencia_afinidad['mes'] = pd.DatetimeIndex(audiencia_afinidad['Fecha_inicio']).month.map(str)
audiencia_afinidad = audiencia_afinidad[audiencia_afinidad.Fecha_inicio > '2018-12-01T00:00:00.000000000'] #solo 2019

#Formato categorias
audiencia_afinidad['Categoría de afinidad (cobertura)'] = audiencia_afinidad.loc[:,'Categoría de afinidad (cobertura)'].str.lower()
tmp = audiencia_afinidad['Categoría de afinidad (cobertura)'].str.split("/", 20, expand=True).iloc[:,:2]
audiencia_afinidad['categoria'] = tmp.iloc[:,0]
audiencia_afinidad['subcategoria'] = tmp.iloc[:,1]

# %% [markdown]
# ### Office Depot

# %% [markdown]
# ## Analisis del Producto

# %% [markdown]
# Contamos con información 2019.
#
# Buscamos conocer mejor la audiencia que ingresa al sitio de Office Depot, con el objetivo de entender:
#
#     ¿Cuales son las principales categorías?
#     ¿Cuales son las subcategorias por categoría?
#
#     ¿Qué categoría genera mayores Ingresos?
#
#     ¿Qué fuentes de Medios tengo dentro de las categorias más importantes?

# %%
audiencia_afinidad.head()
# Out:
#                    Categoría de afinidad (cobertura)  \
# 0                  news & politics/avid news readers
# 1                            shoppers/value shoppers
# 2  food & dining/cooking enthusiasts/30 minute chefs
# 3        lifestyles & hobbies/business professionals
# 4                  news & politics/avid news readers
#
#    Duración media de la sesión      Fuente/Medio  Ingresos  \
# 0                          279      google / cpc  26838280
# 1                          284      google / cpc  26063070
# 2                          280      google / cpc  18926258
# 3                          317      google / cpc  25217850
# 4                          287  google / organic  11693803
#
#    Porcentaje de rebote  Páginas/sesión  Sesiones  \
# 0                     0              10    472635
# 1                     0              10    457417
# 2                     0              10    398757
# 3                     0              11    372224
# 4                     0               9    294790
#
#    Tasa de conversión de comercio electrónico  Transacciones  Usuarios  \
# 0                                           0           5924    285993
# 1                                           0           6030    271956
# 2                                           0           4580    246256
# 3                                           0           5575    218180
# 4                                           0           3079    204577
#
#    Usuarios nuevos                                            archivo  \
# 0           191407  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 1           177035  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 2           166638  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 3           136472  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 4           130399  /home/carlos/Dropbox/Históricos GG/Históricos ...
#
#          cuenta               fechas Fecha_inicio  Fecha_fin mes  \
# 0  Office Depot  [20190501-20190531]   2019-05-01 2019-05-31   5
# 1  Office Depot  [20190501-20190531]   2019-05-01 2019-05-31   5
# 2  Office Depot  [20190501-20190531]   2019-05-01 2019-05-31   5
# 3  Office Depot  [20190501-20190531]   2019-05-01 2019-05-31   5
# 4  Office Depot  [20190501-20190531]   2019-05-01 2019-05-31   5
#
#               categoria            subcategoria
# 0       news & politics       avid news readers
# 1              shoppers          value shoppers
# 2         food & dining     cooking enthusiasts
# 3  lifestyles & hobbies  business professionals
# 4       news & politics       avid news readers

# %% [markdown]
# **¿Cuales son las principales categorias?**

# %%
plt.rcParams['figure.figsize'] = [25, 5]

tmp = analytics_audiencia.groupby(['categoria'],as_index = False).count().iloc[:,[0,1]]

sns.barplot(y = tmp.iloc[:,1], x = tmp.iloc[:,0], 
            estimator = np.mean,
            ci = False,
            data = tmp,
            # Agrega un border a las barras
            edgecolor = 'cadetblue').set_title("Audiencia Office Depote, cuenta con 12 Categorías distintas", size = 20)

plt.xticks(rotation = 45, size=15)

plt.show()

# %% [markdown]
# **¿Cuales son las subcategorias por categoria?**

# %%
plt.style.use('ggplot')

#Podemos cuidar el tamaño de nuestras gráficas en los cuadernos jupyter
plt.rcParams['figure.figsize'] = [20, 10]

#Filtro
tmp = analytics_audiencia.groupby(['subcategoria','categoria']).size().unstack()

# Define a custom palette
color_palette = sns.diverging_palette(220, 10, s=85)

# Pass palette to plot and set axis ranges
sns.heatmap(tmp,
            cmap = color_palette,
            center = 1175,
            vmin = 393,
            vmax = 4145,
            linewidth=1).set_title('Audiencia 2019 Office Depote, distribuida en 12 Categorias y 42 subcategorias')

plt.yticks(rotation = 0, size = 10)
plt.xticks(rotation = 90, size = 15)
plt.show()

# %% [markdown]
# **¿Qué categoría genera mayores Ingresos?**
#
# Top 10 categorias en todo 2019

# %%
tmp = analytics_audiencia.groupby(['categoria','subcategoria'],as_index = False).sum().loc[:,['categoria','subcategoria','Ingresos']]

tmp.sort_values('Ingresos', ascending = False).head(10)
# Out:
#                 categoria            subcategoria  Ingresos
# 28        news & politics       avid news readers 483717768
# 26  media & entertainment            music lovers 356475456
# 4           food & dining     cooking enthusiasts 275236516
# 25  media & entertainment            movie lovers 261904475
# 33               shoppers          value shoppers 240988007
# 11   lifestyles & hobbies  business professionals 236561897
# 35       sports & fitness             sports fans 229318820
# 27  media & entertainment               tv lovers 221445111
# 40                 travel            travel buffs 195495255
# 30               shoppers         luxury shoppers 191139799

# %%
fig = px.sunburst(tmp, path=['categoria', 'subcategoria'], values='Ingresos')

fig.update_layout(legend = {"x":.9,"y":.5},
                  margin=dict(l=20,r=10,b=60,t=80),
                  width=1000,
                  height=1000,
                  title = 'Audiencia 2019 Office Depote, distribuida en 12 Categorias y 42 subcategorias',
                  annotations = [dict(xref='paper',
                                      yref='paper',
                                      x=0.5, y=-0.05,
                                      showarrow=False,
                                      text ='Con mayor participación de medios de entretenimiento y lifestyle & hobbies')],
                  paper_bgcolor='rgb(243, 243, 243)',
                  plot_bgcolor='rgb(243, 243, 243)',
                  template = 'ggplot2')

fig.show()

# %% [markdown]
# ### Petco

# %%
#Union archivos Office Depot
audiencia_afinidad = analytics_funciones.Union_Archivos(Cuenta = ['Petco'], analysis = 'categorias_afinidad', nivel = 'Audiencia')

#Fechas
audiencia_afinidad['fechas'] = [ re.findall( r"\d{8}-\d{8}" ,i) for i in audiencia_afinidad.archivo ]
audiencia_afinidad = analytics_funciones.Formato_Fechas_Analytics(audiencia_afinidad, 'fechas')
audiencia_afinidad['mes'] = pd.DatetimeIndex(audiencia_afinidad['Fecha_inicio']).month.map(str)
audiencia_afinidad = audiencia_afinidad[audiencia_afinidad.Fecha_inicio > '2018-12-01T00:00:00.000000000'] #solo 2019

#Formato categorias
audiencia_afinidad['Categoría de afinidad (cobertura)'] = audiencia_afinidad.loc[:,'Categoría de afinidad (cobertura)'].str.lower()
tmp = audiencia_afinidad['Categoría de afinidad (cobertura)'].str.split("/", 20, expand=True).iloc[:,:2]
audiencia_afinidad['categoria'] = tmp.iloc[:,0]
audiencia_afinidad['subcategoria'] = tmp.iloc[:,1]

# %% [markdown]
# **Top 10 categorias en todo 2019**

# %%
tmp = analytics_audiencia.groupby(['categoria','subcategoria'],as_index = False).sum().loc[:,['categoria','subcategoria','Ingresos']]

tmp.sort_values('Ingresos', ascending = False).head(10)
# Out:
#                 categoria            subcategoria  Ingresos
# 28        news & politics       avid news readers  16360494
# 25  media & entertainment            movie lovers  10872116
# 23  media & entertainment                  gamers   9892593
# 35       sports & fitness             sports fans   9725715
# 33               shoppers          value shoppers   9526292
# 26  media & entertainment            music lovers   8908303
# 4           food & dining     cooking enthusiasts   8677214
# 27  media & entertainment               tv lovers   7815726
# 11   lifestyles & hobbies  business professionals   7621913
# 38             technology            technophiles   7213858

# %%
fig = px.sunburst(tmp, path=['categoria', 'subcategoria'], values='Ingresos')

fig.update_layout(legend = {"x":.9,"y":.5},
                  margin=dict(l=20,r=10,b=60,t=80),
                  width=1000,
                  height=1000,
                  title = 'Audiencia 2019 Petco, distribuida en 12 Categorias y 42 subcategorias',
                  annotations = [dict(xref='paper',
                                      yref='paper',
                                      x=0.5, y=-0.05,
                                      showarrow=False,
                                      text ='Con mayor participación de medios de entretenimiento y lifestyle & hobbies')],
                  paper_bgcolor='rgb(243, 243, 243)',
                  plot_bgcolor='rgb(243, 243, 243)')

fig.show()

# %% [markdown]
# ### RadioShack

# %%
#Union archivos Office Depot
audiencia_afinidad = analytics_funciones.Union_Archivos(Cuenta = ['RadioShack'], analysis = 'categorias_afinidad', nivel = 'Audiencia')

#Fechas
audiencia_afinidad['fechas'] = [ re.findall( r"\d{8}-\d{8}" ,i) for i in audiencia_afinidad.archivo ]
audiencia_afinidad = analytics_funciones.Formato_Fechas_Analytics(audiencia_afinidad, 'fechas')
audiencia_afinidad['mes'] = pd.DatetimeIndex(audiencia_afinidad['Fecha_inicio']).month.map(str)
audiencia_afinidad = audiencia_afinidad[audiencia_afinidad.Fecha_inicio > '2018-12-01T00:00:00.000000000'] #solo 2019

#Formato categorias
audiencia_afinidad['Categoría de afinidad (cobertura)'] = audiencia_afinidad.loc[:,'Categoría de afinidad (cobertura)'].str.lower()
tmp = audiencia_afinidad['Categoría de afinidad (cobertura)'].str.split("/", 20, expand=True).iloc[:,:2]
audiencia_afinidad['categoria'] = tmp.iloc[:,0]
audiencia_afinidad['subcategoria'] = tmp.iloc[:,1]

# %% [markdown]
# **Top 10 categorias en todo 2019**

# %%
tmp = analytics_audiencia.groupby(['categoria','subcategoria'],as_index = False).sum().loc[:,['categoria','subcategoria','Ingresos']]

tmp.sort_values('Ingresos', ascending = False).head(10)
# Out:
#                 categoria            subcategoria  Ingresos
# 28        news & politics       avid news readers  16360494
# 25  media & entertainment            movie lovers  10872116
# 23  media & entertainment                  gamers   9892593
# 35       sports & fitness             sports fans   9725715
# 33               shoppers          value shoppers   9526292
# 26  media & entertainment            music lovers   8908303
# 4           food & dining     cooking enthusiasts   8677214
# 27  media & entertainment               tv lovers   7815726
# 11   lifestyles & hobbies  business professionals   7621913
# 38             technology            technophiles   7213858

# %%
fig = px.sunburst(tmp, path=['categoria', 'subcategoria'], values='Ingresos')

fig.update_layout(legend = {"x":.9,"y":.5},
                  margin=dict(l=20,r=10,b=60,t=80),
                  width=1000,
                  height=1000,
                  title = 'Audiencia 2019 RadioShack, distribuida en 12 Categorias y 42 subcategorias',
                  annotations = [dict(xref='paper',
                                      yref='paper',
                                      x=0.5, y=-0.05,
                                      showarrow=False,
                                      text ='Con mayor participación de medios de entretenimiento y lifestyle & hobbies')],
                  paper_bgcolor='rgb(243, 243, 243)',
                  plot_bgcolor='rgb(243, 243, 243)',
                  template = 'ggplot2')

fig.show()

# %% [markdown]
# **Segmento de Mercado**

# %%
segmentos_intencion_compra = analytics_funciones.Union_Archivos(Cuenta = ['Office Depot'], analysis = 'segmentos_intencion_compra', nivel = 'Audiencia')
segmentos_intencion_compra.head()
# Out:
#    Duración media de la sesión      Fuente/Medio  Ingresos  \
# 0                          275      google / cpc   1880568
# 1                          265  google / organic   1812412
# 2                          283      google / cpc   2234120
# 3                          284  google / organic   1647701
# 4                          292      google / cpc   2073422
#
#    Porcentaje de rebote  Páginas/sesión  \
# 0                     0              10
# 1                     0               9
# 2                     0              11
# 3                     0              10
# 4                     0              11
#
#                                  Segmento de mercado  Sesiones  \
# 0                 Consumer Electronics/Mobile Phones    112871
# 1                 Consumer Electronics/Mobile Phones     92499
# 2  Travel/Trips by Destination/Trips to North Ame...     86429
# 3  Travel/Trips by Destination/Trips to North Ame...     66115
# 4                     Travel/Hotels & Accommodations     71720
#
#    Tasa de conversión de comercio electrónico  Transacciones  Usuarios  \
# 0                                           0            956     64963
# 1                                           0            676     61428
# 2                                           0            977     54903
# 3                                           0            571     47396
# 4                                           0            814     45140
#
#    Usuarios nuevos                                            archivo  \
# 0            37485  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 1            36449  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 2            32518  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 3            28345  /home/carlos/Dropbox/Históricos GG/Históricos ...
# 4            26871  /home/carlos/Dropbox/Históricos GG/Históricos ...
#
#          cuenta               fechas
# 0  Office Depot  [20190601-20190630]
# 1  Office Depot  [20190601-20190630]
# 2  Office Depot  [20190601-20190630]
# 3  Office Depot  [20190601-20190630]
# 4  Office Depot  [20190601-20190630]

# %%
import requests

html = requests.get("https://www.bestbuy.com.mx/c/ofertas-en-computadoras-y-mas/1002222?promo_id=w46_19_hm&promo_name=w46_19_hm_bnc_cop_computadoras46&promo_creative=bnc_cop&promo_position=slot2")
# Out:
# b'\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    <!DOCTYPE HTML>\n<html lang="es" version="20.18.2">\n    <head>\n        <title>Ofertas en computadoras y m\xc3\xa1s</title>\n        <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">\n        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        <meta name="keywords" content="Ofertas en computadoras y m\xc3\xa1s">\n        <link rel="canonical" href="https://www.bestbuy.com.mx/c/ofertas-en-computadoras-y-mas/1002222">\n        <!-- website -->\n        <meta name="description" content="En Best Buy  puedes encontar  grandes  ofertas  en  equipos de  computo, accesorios de  computo, mochilas y mucho m\xc3\xa1s." />\n        <!-- Schema.org markup for Google+ -->\n        <meta itemprop="name" content="Autoridad Mundial en Tecnolog\xc3\xada"/>\n        <meta itemprop="description" content="En Best Buy  puedes encontar  grandes  ofertas  en  equipos de  computo, accesorios de  computo, mochilas y mucho m\xc3\xa1s."/>\n        <meta itemprop="image" content="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/BestBuyLogoStoreLocator.jpg"/>\n        <!-- Twitter Card data -->\n        <meta name="twitter:card" content="Autoridad Mundial en Tecnolog\xc3\xada"/>\n        <meta name="twitter:site" content="@bestbuymexico"/>\n        <meta name="twitter:title" content="Ofertas en computadoras y m\xc3\xa1s">\n        <meta name="twitter:description" content="En Best Buy  puedes encontar  grandes  ofertas  en  equipos de  computo, accesorios de  computo, mochilas y mucho m\xc3\xa1s."/>\n        <meta name="twitter:creator" content="@bestbuymexico"/>\n        <meta name="twitter:image:src" content="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/BestBuyLogoStoreLocator.jpg"/>\n        <!-- Open Graph data -->\n        <meta property="og:title" content="Ofertas en computadoras y m\xc3\xa1s" />\n        <meta property="og:type" content="website" />\n        <meta property="og:url" content="https://www.bestbuy.com.mx/c/ofertas-en-computadoras-y-mas/1002222" />\n        <meta property="og:image" content="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/BestBuyLogoStoreLocator.jpg" />\n        <meta property="og:description" content="En Best Buy  puedes encontar  grandes  ofertas  en  equipos de  computo, accesorios de  computo, mochilas y mucho m\xc3\xa1s." />\n        <meta property="og:site_name" content="Ofertas en computadoras y m\xc3\xa1s" />\n        <meta property="og:locale" content="es_MX"/>\n        <meta charset="utf-8"/>\n        <meta name="viewport" content="width=device-width,maximum-scale=1" />\n        <meta name="google-site-verification" content="zYvzSPIBXVmXXc9dOUBEfr4ih9gKr2tb2HKwXsrOhCY" />\n        <script id="global-scripts">\n            var rx = new RegExp(\'<-/\', \'ig\');\n            function reviver(key, value) {\n                if (typeof value === \'string\') {\n                    return value.replace(rx, \'</\');\n                }\n                return value;\n            }\n\n            window.INITIAL_PAGE_STATE = JSON.parse("{\\"readyState\\":\\"FETCHING_BASE_PAGE_DATA_SUCCESS\\",\\"sort\\":\\"Best-Match\\",\\"size\\":\\"l\\",\\"totalCount\\":266,\\"currentPage\\":1,\\"pageSize\\":24,\\"appliedFacets\\":[],\\"view\\":\\"$(HTTP_COOKIE{\'plp-view\'}|\'LIST_VIEW\')\\",\\"products\\":[{\\"title\\":\\"Asus - Laptop X509FA-BR694T de 15.6\\\\\\" - Pentium Gold - Intel UHD 610 - Memoria 8GB - Disco duro 1TB+SSD 128GB - Plata\\",\\"skuId\\":\\"1000228664\\",\\"itemType\\":\\"product\\",\\"modelNumber\\":\\"X509FA-BR694T\\",\\"publisher\\":\\"\\",\\"releaseDate\\":\\"\\",\\"upc\\":\\"192876566930\\",\\"customerPrice\\":\\"$10,499\\",\\"totalSavings\\":\\"$0\\",\\"regularPrice\\":\\"$10,499\\",\\"shippingOptions\\":[\\"StandardShipping\\",\\"StorePickup\\"],\\"imageURL\\":\\"https://pisces.bbystatic.com/image2/BestBuy_MX/images/products/1000/1000228664_sa.jpg\\",\\"isNew\\":false,\\"seoPdp ...
