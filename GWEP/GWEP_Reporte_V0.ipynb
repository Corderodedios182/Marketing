# %%
from PIL import Image
import os
os.chdir('/home/carlos/Documentos/Adsocial/GWEP')

# %% [markdown]
# Las siguientes gráficas muestran el análisis que se ha realizado en la Tabla Posibles clientes (Leads en Zoho).
#
# - Graficas de forma general sobre la hora de creación, conteo de Leads por desarrollo,  Fuente de Posibles clientes.
# - Analisamos los Leads que realmente nos interesan, Fuente Posible cliente, Estado posible cliente.

# %%
#Conteo de Leads por Hora de Creación
img = Image.open("Conteo_Leads.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=389x276 at 0x7F195A6F8630>

# %%
#Conteo de Leads por Desarrollo
img = Image.open("Conteo_Desarrollo.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=395x367 at 0x7F195A4E7828>

# %%
#Conteo de Fuente de Posibles clientes
img = Image.open("Fuente de Posible cliente_Total.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=401x389 at 0x7F195A4F1B00>

# %%
#Conteo de Leads Mensuales
img = Image.open("Lead_Mensual.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=395x310 at 0x7F195A7B9A58>

# %% [markdown]
# Una analisis de forma general, sabemos que no todo lo que se encuentra en Leads es bueno.
#
# #### Fuente de Posible Clientes

# %% [markdown]
# Facebook y Google tienen una gran participación en los Leads, ¿Como se distribuyen los Estados de Posibles clientes?

# %%
img = Image.open("Fuente_Posible_cliente.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1009x492 at 0x7F195A7F3BE0>

# %% [markdown]
# Estados de posibles clientes, la mayoría son etiquetados como Leads Perdidos y Lead Basura.
#
# Hagamos un zoom sobre los Leads Contactados, Contactar en el futuro y Intento de contacto.

# %%
img = Image.open("Estado_Posible_cliente.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1009x492 at 0x7F195A764BA8>

# %%
img = Image.open("Interes_Lead.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1009x492 at 0x7F195A5187B8>

# %% [markdown]
# Estamos realizando un cruze de información entre la información de las plataformas digitales y el CRM.
# Para incrementar el número de Leads buenos.
