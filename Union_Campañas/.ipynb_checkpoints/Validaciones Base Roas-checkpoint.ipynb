# %% [markdown]
# Una ves que hemos corrido el script que une los archivos mp y fic, debemos validar que la información cuadre.
#
# Primero validaremos la información del mp

# %%
import pandas as pd
import os

os.chdir('/home/carlos/Documentos/3_Adsocial/Marketing/Union_Campañas')
os.listdir()

from librerias import MP_FIC
from librerias import Plataformas
from librerias import Escritura_Sheets

# %%
base_roas = Escritura_Sheets.archivos_finales()

# %%
base_roas.shape
# Out:
# (1760, 46)

# %%
base_roas.keys()
# Out:
# Index(['cliente', 'marca', 'llave_ventas', 'plataforma_abreviacion',
#        'plataforma_x', 'versión', 'fecha_inicio_plan', 'fecha_fin_plan',
#        'mes_plan', 'costo_planeado', 'kpi_planeado', 'serving',
#        'inversión_plataforma', 'inversión_total', 'plan_x', 'inversión_AdOps',
#        'Operativo_AdOps', 'Serving_AdOps', 'costo_operativo', 'conteo_MP_FIC',
#        'plan_y', 'plataforma_y', 'archivo', 'cuenta', 'llave_plataformas',
#        'mes', 'inicio_reporte', 'fin_reporte', 'inicio_campaña', 'fin_campaña',
#        'divisa', 'dinero_gastado', 'impresiones', 'clics', 'conversiones',
#        'revenue', 'conversiones_directas', 'conversiones_asistidas',
#        'revenue_directo', 'revenue_asistido', 'conteo', 'inicio', 'fin',
#        'dias', 'mes_cruze', 'ultima_actualizacion'],
#       dtype='object')

# %% [markdown]
# ## Validación mp
#
# Primero analizaremos las cifras del mp

# %%
#Al traernos la información de google sheets no se respeta el formato, todo se mantiene en object
base_roas.costo_planeado = base_roas.costo_planeado.apply(lambda x : float(x))
base_roas.kpi_planeado = base_roas.kpi_planeado.apply(lambda x: str(x).replace(',','')).astype('int')
base_roas.serving = base_roas.serving.apply(lambda x: str(x).replace(',','')).astype('int')
base_roas.inversión_plataforma = base_roas.inversión_plataforma.apply(lambda x: str(x).replace(',','')).astype('int')
base_roas.inversión_total = base_roas.inversión_total.apply(lambda x: str(x).replace(',','')).astype('int')

# %%
#La información del mp llega hasta la columna plan_x
mp = base_roas.loc[:,:'plan_x']

# %%
mp.head()
# Out:
#   cliente             marca                           llave_ventas  \
# 1   GICSA  Explanada Puebla   2001_gicsa_explanadapuebla_pi_mkt_FB
# 2   GICSA  Explanada Puebla   2001_gicsa_explanadapuebla_pi_mkt_FB
# 3   GICSA  Explanada Puebla   2001_gicsa_explanadapuebla_pi_mkt_FB
# 4   GICSA  Explanada Puebla   2001_gicsa_explanadapuebla_pi_mkt_FB
# 5   GICSA  Explanada Puebla  2001_gicsa_explanadapuebla_pi_mkt_SEM
#
#   plataforma_abreviacion          plataforma_x versión fecha_inicio_plan  \
# 1                     FB  Facebook / Instagram      V2          1/1/2020
# 2                     FB  Facebook / Instagram      V2          1/1/2020
# 3                     FB  Facebook / Instagram      V2          1/1/2020
# 4                     FB  Facebook / Instagram      V2          1/1/2020
# 5                    SEM         Google Search      V2          1/1/2020
#
#   fecha_fin_plan mes_plan  costo_planeado  kpi_planeado  serving  \
# 1      31/1/2020    Enero            3.83          6500        0
# 2      31/1/2020    Enero            3.83          6500        0
# 3      31/1/2020    Enero            3.83          6500        0
# 4      31/1/2020    Enero            3.83          6500        0
# 5      31/1/2020    Enero           12.00           716        0
#
#    inversión_plataforma  inversión_total plan_x
# 1                 25800            25800     MP
# 2                 25800            25800     MP
# 3                 25800            25800     MP
# 4                 25800            25800     MP
# 5                  8600             8600     MP

# %%
mp.mes_plan.value_counts()
# Out:
# Febrero    679
# Enero      560
# Marzo      521
# Name: mes_plan, dtype: int64

# %%
enero_prueba = mp[(mp.cliente == 'GICSA') & (mp.marca == 'Forum Cuernavaca') & (mp.mes_plan == 'Enero') ]

enero_prueba
# Out:
#     cliente             marca                           llave_ventas  \
# 17    GICSA  Forum Cuernavaca   2001_gicsa_forumcuernavaca_pi_mkt_FB
# 18    GICSA  Forum Cuernavaca   2001_gicsa_forumcuernavaca_pi_mkt_FB
# 19    GICSA  Forum Cuernavaca   2001_gicsa_forumcuernavaca_pi_mkt_FB
# 20    GICSA  Forum Cuernavaca   2001_gicsa_forumcuernavaca_pi_mkt_FB
# 21    GICSA  Forum Cuernavaca  2001_gicsa_forumcuernavaca_pi_mkt_SEM
# 22    GICSA  Forum Cuernavaca  2001_gicsa_forumcuernavaca_pi_mkt_SEM
# 23    GICSA  Forum Cuernavaca  2001_gicsa_forumcuernavaca_pi_mkt_SEM
# 499   GICSA  Forum Cuernavaca   2001_gicsa_forumcuernavaca_pi_mkt_FB
#
#     plataforma_abreviacion          plataforma_x versión fecha_inicio_plan  \
# 17                      FB  Facebook / Instagram      V2          1/1/2020
# 18                      FB  Facebook / Instagram      V2          1/1/2020
# 19                      FB  Facebook / Instagram      V2          1/1/2020
# 20                      FB  Facebook / Instagram      V2          1/1/2020
# 21                     SEM         Google Search      V2          1/1/2020
# 22                     SEM         Google Search      V2          1/1/2020
# 23                     SEM         Google Search      V2          1/1/2020
# 499                     FB  Facebook / Instagram      V2          1/1/2020
#
#     fecha_fin_plan mes_plan  costo_planeado  kpi_planeado  serving  \
# 17       31/1/2020    Enero            3.83          6526        0
# 18       31/1/2020    Enero            3.83          6526        0
# 19       31/1/2020    Enero            3.83          6526        0
# 20       31/1/2020    Enero            3.83          6526        0
# 21       31/1/2020    Enero           12.00           716        0
# 22       31/1/2020    Enero           12.00           716        0
# 23       31/1/2020    Enero           12.00           716        0
# 499      31/1/2020    Enero            3.83          6526        0
#
#      inversión_plataforma  inversión_total plan_x
# 17                  25800            25800     MP
# 18                  25800            25800     MP
# 19                  25800            25800     MP
# 20                  25800            25800     MP
# 21                   8600             8600     MP
# 22                   8600             8600     MP
# 23                   8600             8600     MP
# 499                 25800            25800     MP

# %%
enero_prueba.groupby(['cliente','marca','mes_plan','versión','plataforma_x'], as_index = False).agg({'costo_planeado':'mean',
                                                                                              'kpi_planeado':'mean',
                                                                                              'serving':'mean',
                                                                                              'inversión_plataforma':'mean',
                                                                                              'inversión_total':'mean'})
# Out:
#   cliente             marca mes_plan versión          plataforma_x  \
# 0   GICSA  Forum Cuernavaca    Enero      V2  Facebook / Instagram
# 1   GICSA  Forum Cuernavaca    Enero      V2         Google Search
#
#    costo_planeado  kpi_planeado  serving  inversión_plataforma  \
# 0            3.83          6526        0                 25800
# 1           12.00           716        0                  8600
#
#    inversión_total
# 0            25800
# 1             8600

# %%
enero_prueba = mp[(mp.cliente == 'GICSA') & (mp.mes_plan == 'Enero') ]

enero_prueba.groupby(['cliente','marca','mes_plan','versión','plataforma_x'], as_index = False).agg({'costo_planeado':'mean',
                                                                                              'kpi_planeado':'mean',
                                                                                              'serving':'mean',
                                                                                              'inversión_plataforma':'mean',
                                                                                              'inversión_total':'mean'})
# Out:
#    cliente             marca mes_plan versión          plataforma_x  \
# 0    GICSA  Explanada Puebla    Enero      V2  Facebook / Instagram
# 1    GICSA  Explanada Puebla    Enero      V2         Google Search
# 2    GICSA  Explanda Pachuca    Enero      V2  Facebook / Instagram
# 3    GICSA  Explanda Pachuca    Enero      V2         Google Search
# 4    GICSA  Forum Cuernavaca    Enero      V2  Facebook / Instagram
# 5    GICSA  Forum Cuernavaca    Enero      V2         Google Search
# 6    GICSA       Isla Mérida    Enero      V2  Facebook / Instagram
# 7    GICSA       Isla Mérida    Enero      V2         Google Search
# 8    GICSA  Paseo Interlomas    Enero      V2  Facebook / Instagram
# 9    GICSA  Paseo Interlomas    Enero      V2         Google Search
# 10   GICSA        Querétaro     Enero      V2  Facebook / Instagram
# 11   GICSA        Querétaro     Enero      V2         Google Search
#
#     costo_planeado  kpi_planeado  serving  inversión_plataforma  \
# 0             3.83          6500        0                 25800
# 1            12.00           716        0                  8600
# 2             3.67          7754        0                 30100
# 3            12.00          1075        0                 12900
# 4             3.83          6526        0                 25800
# 5            12.00           716        0                  8600
# 6             3.83          6807        0                 25800
# 7            12.00           716        0                  8600
# 8             3.83          9114        0                 34400
# 9            12.00          1434        0                 17200
# 10            3.83         15994        0                 58480
# 11           12.00          1792        0                 21500
#
#     inversión_total
# 0             25800
# 1              8600
# 2             30100
# 3             12900
# 4             25800
# 5              8600
# 6             25800
# 7              8600
# 8             34400
# 9             17200
# 10            58480
# 11            21500
